# %% [markdown]
# <a href="https://colab.research.google.com/github/danielmancovidales/Aplicaciones-en-salud/blob/main/prepro_egresos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Librerias generales
import pandas as pd
import numpy as np
import re
# Librerias y visualización
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Leer base de datos
df_egresos = pd.read_csv('/content/drive/MyDrive/analitica3/Salud/RETO_df_egresos.csv', encoding='latin1', sep=',', low_memory= False)
df_egresos
# Out:
#       YEAR        MES  NRO ATENCION  NRO INGRESO  SERVICIO HABILITADO COD  \
# 0     2017       MAYO       3433964      1899917                     -1.0
# 1     2017  DICIEMBRE       3720631      2018136                     -1.0
# 2     2018    FEBRERO       3912821      2159592                    501.0
# 3     2018       MAYO       4023613      2254075                    501.0
# 4     2018      JULIO       4080166      2292863                    101.0
# ...    ...        ...           ...          ...                      ...
# 6371  2021      MARZO       5534142      3741912                    101.0
# 6372  2018    FEBRERO       3887839      2138151                    101.0
# 6373  2018      MARZO       3961138      2204868                    101.0
# 6374  2021  NOVIEMBRE       5883105      4110965                    101.0
# 6375  2021    OCTUBRE       5857866      4084538                    107.0
#
#              SERVICIO HABILITADO TIPO IDENTIFICACION  NRODOC  \
# 0                Sin Informacion                  CC  308185
# 1                Sin Informacion                  CC  308185
# 2          Urgencias >= 24 horas                  CC  308185
# 3          Urgencias >= 24 horas                  CC  308185
# 4                General adultos                  CC  308185
# ...                          ...                 ...     ...
# 6371             General adultos                  CC  312056
# 6372             General adultos                  CC  308757
# 6373             General adultos                  CC  308759
# 6374             General adultos                  CC  313987
# 6375  Cuidado Intermedio Adultos                  CC  313921
#
#              FECHA NACIMIENTO REGIMEN AFILIACION  ...  \
# 0     1937-07-18 00:00:00.000   Sin informaciÃ³n  ...
# 1     1937-07-18 00:00:00.000   Sin informaciÃ³n  ...
# 2     1937-07-18 00:00:00.000       Contributivo  ...
# 3     1937-07-18 00:00:00.000       Contributivo  ...
# 4     1937-07-18 00:00:00.000       Contributivo  ...
# ...                       ...                ...  ...
# 6371  1949-05-09 00:00:00.000       Contributivo  ...
# 6372  1951-06-08 00:00:00.000       Contributivo  ...
# 6373  1935-09-29 00:00:00.000       Contributivo  ...
# 6374  1953-09-30 00:00:00.000       Contributivo  ...
# 6375  1960-06-09 00:00:00.000       Contributivo  ...
#
#      DX PRINCIPAL EGRESO CAPITULO COD  \
# 0                             J00-J99
# 1                             J00-J99
# 2                             J00-J99
# 3                             I00-I99
# 4                             I00-I99
# ...                               ...
# 6371                          I00-I99
# 6372                          J00-J99
# 6373                          S00-T98
# 6374                          N00-N99
# 6375                          I00-I99
#
#                            DX PRINCIPAL EGRESO CAPITULO  \
# 0                ENFERMEDADES DEL SISTEMA RESPIRATORIO
# 1                ENFERMEDADES DEL SISTEMA RESPIRATORIO
# 2                ENFERMEDADES DEL SISTEMA RESPIRATORIO
# 3                ENFERMEDADES DEL SISTEMA CIRCULATORIO
# 4                ENFERMEDADES DEL SISTEMA CIRCULATORIO
# ...                                                 ...
# 6371             ENFERMEDADES DEL SISTEMA CIRCULATORIO
# 6372             ENFERMEDADES DEL SISTEMA RESPIRATORIO
# 6373  TRAUMATISMOS, ENVENENAMIENTO Y ALGUNAS OTRAS C...
# 6374           ENFERMEDADES DEL SISTEMA GENITOURINARIO
# 6375             ENFERMEDADES DEL SISTEMA CIRCULATORIO
#
#      CAUSA BASICA MUERTE COD               CAUSA BASICA MUERTE  \
# 0                        NaN  Sin informacion en base de datos
# 1                        NaN  Sin informacion en base de datos
# 2                        NaN  Sin informacion en base de datos
# 3                        NaN  Sin informacion en base de datos
# 4                        NaN  Sin informacion en base de datos
# ...                      ...                               ...
# 6371                     NaN  Sin informacion en base de datos
# 6372                     NaN  Sin informacion en base de datos
# 6373                     NaN  Sin informacion en base de datos
# 6374                     NaN  Sin informacion en base de datos
# 6375                     NaN  Sin informacion en base de datos
#
#      CAUSA BASICA CATEGORIA COD            CAUSA BASICA CATEGORIA  \
# 0                           NaN  Sin informacion en base de datos
# 1                           NaN  Sin informacion en base de datos
# 2                           NaN  Sin informacion en base de datos
# 3                           NaN  Sin informacion en base de datos
# 4                           NaN  Sin informacion en base de datos
# ...                         ...                               ...
# 6371                        NaN  Sin informacion en base de datos
# 6372                        NaN  Sin informacion en base de datos
# 6373                        NaN  Sin informacion en base de datos
# 6374                        NaN  Sin informacion en base de datos
# 6375                        NaN  Sin informacion en base de datos
#
#      CAUSA BASICA CAPITULO COD             CAUSA BASICA CAPITULO  \
# 0                          NaN  Sin informacion en base de datos
# 1                          NaN  Sin informacion en base de datos
# 2                          NaN  Sin informacion en base de datos
# 3                          NaN  Sin informacion en base de datos
# 4                          NaN  Sin informacion en base de datos
# ...                        ...                               ...
# 6371                       NaN  Sin informacion en base de datos
# 6372                       NaN  Sin informacion en base de datos
# 6373                       NaN  Sin informacion en base de datos
# 6374                       NaN  Sin informacion en base de datos
# 6375                       NaN  Sin informacion en base de datos
#
#               PROFESIONAL ESPECIALIDAD  \
# 0     Sin informacion en Base de datos
# 1     Sin informacion en Base de datos
# 2                     Medicina Interna
# 3                     Medicina Interna
# 4                     Medicina Interna
# ...                                ...
# 6371                  Medicina Interna
# 6372                  Medicina Interna
# 6373                         Ortopedia
# 6374                  Medicina Interna
# 6375                  Medicina Interna
#
#                      PROFESIONAL ESPECIALIDAD GRD
# 0                                Medicina Interna
# 1                                Medicina Interna
# 2                                    Urgentologia
# 3                                    Urgentologia
# 4                                Medicina Interna
# ...                                           ...
# 6371                                   Neurologia
# 6372                                 Infectologia
# 6373  Cirugia Plastica- Maxilofacial y de la Mano
# 6374                             Medicina Interna
# 6375                                   Nefrologia
#
# [6376 rows x 66 columns]
